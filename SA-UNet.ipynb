# %%
from  SA_UNet import *
model=SA_UNet(input_size=(224,224,3),start_neurons=16,lr=1e-3,keep_prob=0.87,block_size=7)
# Out:
# 2024-04-15 15:16:47.142984: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-04-15 15:16:47.143003: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-04-15 15:16:47.143008: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-04-15 15:16:47.143035: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-15 15:16:47.143052: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 224, 224, 16)         448       ['input_1[0][0]']
#
#  drop_block2d (DropBlock2D)  (None, 224, 224, 16)         0         ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 224, 224, 16)         64        ['drop_block2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 224, 224, 16)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 16)         2320      ['activation[0][0]']
#
#  drop_block2d_1 (DropBlock2  (None, 224, 224, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  batch_normalization_1 (Bat  (None, 224, 224, 16)         64        ['drop_block2d_1[0][0]']
#  chNormalization)
#
# ...
